# %%
#Import Dependencies

import pandas as pd

# %%
# Write file path

path = "Resources/cities_weather.csv"

# %%
# Read file

weather_data = pd.read_csv(path)
weather_data
# Out:
#           Cities Countries  Latitude  Longitude  Max Temperature (F)  \
# 0         Vuktyl        RU     63.86      57.31                -19.3
# 1      Busselton        AU    -33.65     115.33                 55.0
# 2    Provideniya        RU     64.38    -173.30                 -5.3
# 3      Boyolangu        ID     -8.12     111.89                 75.5
# 4        Honiara        SB     -9.43     159.95                 78.6
# ..           ...       ...       ...        ...                  ...
# 540        Macau        BR     -5.12     -36.63                 85.1
# 541    Maiduguri        NG     11.85      13.16                 74.9
# 542    Kurayoshi        JP     35.43     133.82                 35.6
# 543     Lichinga        MZ    -13.31      35.24                 69.8
# 544   Port Keats        AU    -14.25     129.55                 78.9
#
#      Humidity (%)  Cloudiness  Wind Speed (mph)        Date
# 0              88          93               1.6  02-09-2021
# ...

# %%
# Convert to html

weather_table = weather_data.to_html()
weather_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Cities</th>\n      <th>Countries</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Max Temperature (F)</th>\n      <th>Humidity (%)</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed (mph)</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Vuktyl</td>\n      <td>RU</td>\n      <td>63.86</td>\n      <td>57.31</td>\n      <td>-19.3</td>\n      <td>88</td>\n      <td>93</td>\n      <td>1.6</td>\n      <td>02-09-2021</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Busselton</td>\n      <td>AU</td>\n      <td>-33.65</td>\n      <td>115.33</td>\n      <td>55.0</td>\n      <td>97</td>\n      <td>90</td>\n      <td>6.8</td>\n      <td>02-09-2021</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Provideniya</td>\n      <td>RU</td>\n      <td>64.38</td>\n      <td>-173.30</td>\n      <td>-5.3</td>\n    
# ...

# %%
# Strip newlines

weather_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Cities</th>      <th>Countries</th>      <th>Latitude</th>      <th>Longitude</th>      <th>Max Temperature (F)</th>      <th>Humidity (%)</th>      <th>Cloudiness</th>      <th>Wind Speed (mph)</th>      <th>Date</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>Vuktyl</td>      <td>RU</td>      <td>63.86</td>      <td>57.31</td>      <td>-19.3</td>      <td>88</td>      <td>93</td>      <td>1.6</td>      <td>02-09-2021</td>    </tr>    <tr>      <th>1</th>      <td>Busselton</td>      <td>AU</td>      <td>-33.65</td>      <td>115.33</td>      <td>55.0</td>      <td>97</td>      <td>90</td>      <td>6.8</td>      <td>02-09-2021</td>    </tr>    <tr>      <th>2</th>      <td>Provideniya</td>      <td>RU</td>      <td>64.38</td>      <td>-173.30</td>      <td>-5.3</td>      <td>77</td>      <td>0</td>      <td>13.9</td>      <td>02-09-2021</td>    </tr>    <tr>    
# ...

# %%
# Save file

weather_data.to_html('weather_table.html')
